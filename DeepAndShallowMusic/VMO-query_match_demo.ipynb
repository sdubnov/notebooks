# %% [markdown]
# # PyOracle query/match function test

# %%
# %load_ext autoreload
# %autoreload 2
import factoracle as fa
import Resources.analysis as an
import Resources.generate as ge
import Resources.helpers as helpers
import numpy as np
import matplotlib.pyplot as plt
from bregman.suite import Chromagram

# %matplotlib inline
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-9622914d42ce> in <module>()
#       1 get_ipython().magic(u'load_ext autoreload')
#       2 get_ipython().magic(u'autoreload 2')
# ----> 3 import factoracle as fa
#       4 import Resources.analysis as an
#       5 import Resources.generate as ge
#
# ImportError: No module named factoracle

# %% [markdown]
# ## Load wavfile and plot chroma

# %%
targetfile = 'FunkBass.wav' #prokofiev 'hmmtesttone.wav'
# targetfile = 'hmmtesttone.wav'
qfilename = 'audio_query_test.wav'
sfilename = 'audio_shuffled_test.wav'


fft_size = 8192
hop_size = fft_size/2
chroma = Chromagram(targetfile, log10=True, intensify=True, nfft=fft_size, wfft=fft_size, nhop=hop_size)

plt.figure()
plt.imshow(chroma.X, aspect = 'auto', origin = 'lower', interpolation = 'nearest', cmap ='Greys')
plt.title('Chromagram', fontsize = 18)
plt.xlabel('Frame', fontsize = 14)
plt.ylabel('Chroma Bin(1 = C, 3 = E ...)', fontsize = 14)

plt.figure()
plt.stem(np.sqrt(np.sum(np.diff(chroma.X)**2,0)))
plt.grid(b = 'on')
plt.xlim((0, 55))
plt.title('2-norm between Chroma frames', fontsize = 18)
plt.xlabel('Frame', fontsize = 14)
plt.ylabel('2-norm', fontsize = 14)

# %% [markdown]
# ## Calculate ideal threhold via IR

# %%
features = {}
frames_per = 1
chroma_frames = [[0]] * len(chroma.X[0])
for i, frame in enumerate(chroma.X[0]):
    chroma_frames[i] = [component[i] for component in chroma.X]
features['chroma'] = chroma_frames

r = (0.0000, 0.002, 0.00001) 
#ideal_t = fa.calculate_ideal_threshold(r, features, 'chroma', frames_per_state=frames_per, ir_type='cum', VERBOSE = False)
ideal_t = fa.calculate_ideal_threshold(r, features, 'chroma', frames_per_state=frames_per, ir_type='cum')
x_a = [i[1] for i in ideal_t[1]]
y_a = [i[0] for i in ideal_t[1]]
plt.figure()
plt.plot(x_a, y_a, linewidth = 2)
plt.title('IR vs. Threshold Value', fontsize = 18)
plt.grid(b = 'on')
plt.xlabel('Threshold', fontsize = 14)
plt.ylabel('IR', fontsize = 14)
# Out:
# testing threshold: 0.0
# testing threshold: 1e-05
# testing threshold: 2e-05
# testing threshold: 3e-05
# testing threshold: 4e-05
# testing threshold: 5e-05
# testing threshold: 6e-05
# testing threshold: 7e-05
# testing threshold: 8e-05
# testing threshold: 9e-05
# testing threshold: 0.0001
# testing threshold: 0.00011
# testing threshold: 0.00012
# testing threshold: 0.00013
# testing threshold: 0.00014
# testing threshold: 0.00015
# testing threshold: 0.00016
# testing threshold: 0.00017
# testing threshold: 0.00018
# testing threshold: 0.00019
# testing threshold: 0.0002
# testing threshold: 0.00021
# testing threshold: 0.00022
# testing threshold: 0.00023
# testing threshold: 0.00024
# testing threshold: 0.00025
# testing threshold: 0.00026
# testing threshold: 0.00027
# testing threshold: 0.00028
# testing threshold: 0.00029
# testing threshold: 0.0003
# testing threshold: 0.00031
# testing threshold: 0.00032
# testing threshold: 0.00033
# testing threshold: 0.00034
# testing threshold: 0.00035
# testing threshold: 0.00036
# testing threshold: 0.00037
# testing threshold: 0.00038
# testing threshold: 0.00039
# testing threshold: 0.0004
# testing threshold: 0.00041
# testing threshold: 0.00042
# testing threshold: 0.00043
# testing threshold: 0.00044
# testing threshold: 0.00045
# testing threshold: 0.00046
# testing threshold: 0.00047
# testing threshold: 0.00048
# testing threshold: 0.00049
# testing threshold: 0.0005
# testing threshold: 0.00051
# testing threshold: 0.00052
# testing threshold: 0.00053
# testing threshold: 0.00054
# testing threshold: 0.00055
# testing threshold: 0.00056
# testing threshold: 0.00057
# testing threshold: 0.00058
# testing threshold: 0.00059
# testing threshold: 0.0006
# testing threshold: 0.00061
# testing threshold: 0.00062
# testing threshold: 0.00063
# testing threshold: 0.00064
# testing threshold: 0.00065
# testing threshold: 0.00066
# testing threshold: 0.00067
# testing threshold: 0.00068
# testing threshold: 0.00069
# testing threshold: 0.0007
# testing threshold: 0.00071
# testing threshold: 0.00072
# testing threshold: 0.00073
# testing threshold: 0.00074
# testing threshold: 0.00075
# testing threshold: 0.00076
# testing threshold: 0.00077
# testing threshold: 0.00078
# testing threshold: 0.00079
# testing threshold: 0.0008
# testing threshold: 0.00081
# testing threshold: 0.00082
# testing threshold: 0.00083
# testing threshold: 0.00084
# testing threshold: 0.00085
# testing threshold: 0.00086
# testing threshold: 0.00087
# testing threshold: 0.00088
# testing threshold: 0.00089
# testing threshold: 0.0009
# testing threshold: 0.00091
# testing threshold: 0.00092
# testing threshold: 0.00093
# testing threshold: 0.00094
# testing threshold: 0.00095
# testing threshold: 0.00096
# testing threshold: 0.00097
# testing threshold: 0.00098
# testing threshold: 0.00099
# testing threshold: 0.001
# testing threshold: 0.00101
# testing threshold: 0.00102
# testing threshold: 0.00103
# testing threshold: 0.00104
# testing threshold: 0.00105
# testing threshold: 0.00106
# testing threshold: 0.00107
# testing threshold: 0.00108
# testing threshold: 0.00109
# testing threshold: 0.0011
# testing threshold: 0.00111
# testing threshold: 0.00112
# testing threshold: 0.00113
# testing threshold: 0.00114
# testing threshold: 0.00115
# testing threshold: 0.00116
# testing threshold: 0.00117
# testing threshold: 0.00118
# testing threshold: 0.00119
# testing threshold: 0.0012
# testing threshold: 0.00121
# testing threshold: 0.00122
# testing threshold: 0.00123
# testing threshold: 0.00124
# testing threshold: 0.00125
# testing threshold: 0.00126
# testing threshold: 0.00127
# testing threshold: 0.00128
# testing threshold: 0.00129
# testing threshold: 0.0013
# testing threshold: 0.00131
# testing threshold: 0.00132
# testing threshold: 0.00133
# testing threshold: 0.00134
# testing threshold: 0.00135
# testing threshold: 0.00136
# testing threshold: 0.00137
# testing threshold: 0.00138
# testing threshold: 0.00139
# testing threshold: 0.0014
# testing threshold: 0.00141
# testing threshold: 0.00142
# testing threshold: 0.00143
# testing threshold: 0.00144
# testing threshold: 0.00145
# testing threshold: 0.00146
# testing threshold: 0.00147
# testing threshold: 0.00148
# testing threshold: 0.00149
# testing threshold: 0.0015
# testing threshold: 0.00151
# testing threshold: 0.00152
# testing threshold: 0.00396
# testing threshold: 0.00397
# testing threshold: 0.00398
# testing threshold: 0.00399
# testing threshold: 0.004
# testing threshold: 0.00401
# testing threshold: 0.00402
# testing threshold: 0.00403
# testing threshold: 0.00404
# testing threshold: 0.00405
# testing threshold: 0.00406
# testing threshold: 0.00407
# testing threshold: 0.00408
# testing threshold: 0.00409
# testing threshold: 0.0041
# testing threshold: 0.00411
# testing threshold: 0.00412
# testing threshold: 0.00413
# testing threshold: 0.00414
# testing threshold: 0.00415
# testing threshold: 0.00416
# testing threshold: 0.00417
# testing threshold: 0.00418
# testing threshold: 0.00419
# testing threshold: 0.0042
# testing threshold: 0.00421
# testing threshold: 0.00422
# testing threshold: 0.00423
# testing threshold: 0.00424
# testing threshold: 0.00425
# testing threshold: 0.00426
# testing threshold: 0.00427
# testing threshold: 0.00428
# testing threshold: 0.00429
# testing threshold: 0.0043
# testing threshold: 0.00431
# testing threshold: 0.00432
# testing threshold: 0.00433
# testing threshold: 0.00434
# testing threshold: 0.00435
# testing threshold: 0.00436
# testing threshold: 0.00437
# testing threshold: 0.00438
# testing threshold: 0.00439
# testing threshold: 0.0044
# testing threshold: 0.00441
# testing threshold: 0.00442
# testing threshold: 0.00443
# testing threshold: 0.00444
# testing threshold: 0.00445
# testing threshold: 0.00446
# testing threshold: 0.00447
# testing threshold: 0.00448
# testing threshold: 0.00449
# testing threshold: 0.0045
# testing threshold: 0.00451
# testing threshold: 0.00452
# testing threshold: 0.00453
# testing threshold: 0.00454
# testing threshold: 0.00455
# testing threshold: 0.00456
# testing threshold: 0.00457
# testing threshold: 0.00458
# testing threshold: 0.00459
# testing threshold: 0.0046
# testing threshold: 0.00461
# testing threshold: 0.00462
# testing threshold: 0.00463
# testing threshold: 0.00464
# testing threshold: 0.00465
# testing threshold: 0.00466
# testing threshold: 0.00467
# testing threshold: 0.00468
# testing threshold: 0.00469
# testing threshold: 0.0047
# testing threshold: 0.00471
# testing threshold: 0.00472
# testing threshold: 0.00473
# testing threshold: 0.00474
# testing threshold: 0.00475
# testing threshold: 0.00476
# testing threshold: 0.00477
# testing threshold: 0.00478
# testing threshold: 0.00479
# testing threshold: 0.0048
# testing threshold: 0.00481
# testing threshold: 0.00482
# testing threshold: 0.00483
# testing threshold: 0.00484
# testing threshold: 0.00485
# testing threshold: 0.00486
# testing threshold: 0.00487
# testing threshold: 0.00488
# testing threshold: 0.00489
# testing threshold: 0.0049
# testing threshold: 0.00491
# testing threshold: 0.00492
# testing threshold: 0.00493
# testing threshold: 0.00494
# testing threshold: 0.00495
# testing threshold: 0.00496
# testing threshold: 0.00497
# testing threshold: 0.00498
# testing threshold: 0.00499

# %% [markdown]
# ## Construct target Audio Oracle

# %%
t_oracle = fa.make_oracle(ideal_t[0][1], 'a', features, 'chroma', frames_per_state=frames_per)

# %%
img = fa.draw_oracle(t_oracle, 'boutput.png', size=(1200, 400))
print img
# Out:
# None

# %%
plt.figure()
f = plt.gca()
plt.imshow(np.asarray(img), aspect = 'auto')
f.axes.xaxis.set_ticklabels([])
f.axes.yaxis.set_ticklabels([])
plt.title('Oracle Structure', fontsize = 18)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-e1f67ed5d9bb> in <module>()
#       5 plt.figure()
#       6 f = plt.gca()
# ----> 7 plt.imshow(np.asarray(img), aspect = 'auto')
#       8 f.axes.xaxis.set_ticklabels([])
#       9 f.axes.yaxis.set_ticklabels([])
#
# /Users/sdubnov/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3020                         filternorm=filternorm, filterrad=filterrad,
#    3021                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3022                         **kwargs)
#    3023     finally:
#    3024         ax.hold(washold)
#
# /Users/sdubnov/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/sdubnov/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    4945                               resample=resample, **kwargs)
#    4946
# -> 4947         im.set_data(X)
#    4948         im.set_alpha(alpha)
#    4949         if im.get_clip_path() is None:
#
# /Users/sdubnov/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/image.pyc in set_data(self, A)
#     447         if (self._A.dtype != np.uint8 and
#     448                 not np.can_cast(self._A.dtype, np.float)):
# --> 449             raise TypeError("Image data can not convert to float")
#     450
#     451         if (self._A.ndim not in (2, 3) or
#
# TypeError: Image data can not convert to float

# %% [markdown]
# ## Test with querying itself - perfect reconstruction expected

# %%
query_events = helpers.features_to_events(features)
path_1, cost_1, i_hat_1 = an.query_complete(t_oracle, query_events, method = 'complete')
print '================='
print 'Query with itself'
print '================='
print 'Perfect reconstruction:'
if path_1[i_hat_1] == range(1,t_oracle.n_states):
    print 'Passed with cost '+ str(cost_1[i_hat_1]) 
else:
    print 'Failed with cost '+ str(cost_1[i_hat_1])
# Out:
# =================
# Query with itself
# =================
# Perfect reconstruction:
# Passed with cost 0.0

# %% [markdown]
# ## Test with shuffled version

# %% [markdown]
# By current query/matching strategy, the query is sub optimal in the sense that it only considers forward links and the current state as possible next state, but the shuffled sequence generated by PyOracle could have the next state the forward states along the suffix links. I.e, for state k, the query function considers {trn[k],k} as possible next state while the generate function in PyOracle considers trn[sfx[k]] as possible next state as well.

# %%
s, _kend, _ktrace = ge.generate(t_oracle, 
                                20, 
                                0.1, 
                                0, LRS = 1, 
                                weight='weight')
query = {}
query_features = [chroma_frames[_s-1] for _s in s]
query['chroma'] = query_features

query_events2 = []
keys = query.keys()
num_events = len(query[keys[0]])
for i in range(num_events):
    new_event = {}
    for key in keys:
        new_event[key] = query[key][i]
    query_events2.append(new_event)    

path, cost, i_hat = an.query_complete(t_oracle, query_events2, method = 'complete')

print '============================'
print 'Query with shuffled original'
print '============================'
print 'Perfect reconstruction:'
if path[i_hat] == s:
    print 'Passed with cost '+ str(cost[i_hat]) 
else:
    print 'Failed with cost '+ str(cost[i_hat])
print 'Retrieved path: ', path[i_hat] 
print 'Shuffled path:  ', s
# Out:
# ============================
# Query with shuffled original
# ============================
# Perfect reconstruction:
# Passed with cost 0.0
# Retrieved path:  [1, 2, 4, 5, 6, 7, 80, 81, 82, 8, 81, 82, 71, 72, 73, 75, 76, 76, 77, 54]
# Shuffled path:   [1, 2, 4, 5, 6, 7, 80, 81, 82, 8, 81, 82, 71, 72, 73, 75, 76, 76, 77, 54]

# %%
ge.audio_synthesis(targetfile, qfilename, path[i_hat], fft_size, hop_size)
ge.audio_synthesis(targetfile, sfilename, s, fft_size, hop_size)
# Out:
# (array([ 0.,  3.,  8., ...,  0.,  0.,  0.]),
#  array([  1.00000000e-05,   1.01471045e-05,   1.05884178e-05, ...,
#           1.05884178e-05,   1.01471045e-05,   1.00000000e-05]))
